# %% [markdown]
# #### importing modules

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### importing dataset

# %%
df = pd.read_csv(r"C:\Users\LENOVO\Downloads\archive\SampleSuperstore.csv")

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# **Representation**
# in our dataset we have 9994 rows and 13 columns

# %%
df.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %% [markdown]
# **information about our dataset**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.drop(["Postal Code"],axis = 1,inplace = True)

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %% [markdown]
# ### Duplicates

# %% [markdown]
# #### removing duplicates

# %%
df.duplicated().sum()
# Out:
# 49

# %%
df.drop_duplicates(keep = 'first',inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### structural errors

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Region',
#        'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
df['Ship Mode'].dtypes
# Out:
# dtype('O')

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df['Segment'].dtypes
# Out:
# dtype('O')

# %%
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
df['Country'].dtypes
# Out:
# dtype('O')

# %%
df['City'].unique()
# Out:
# array(['Henderson', 'Los Angeles', 'Fort Lauderdale', 'Concord',
#        'Seattle', 'Fort Worth', 'Madison', 'West Jordan', 'San Francisco',
#        'Fremont', 'Philadelphia', 'Orem', 'Houston', 'Richardson',
#        'Naperville', 'Melbourne', 'Eagan', 'Westland', 'Dover',
#        'New Albany', 'New York City', 'Troy', 'Chicago', 'Gilbert',
#        'Springfield', 'Jackson', 'Memphis', 'Decatur', 'Durham',
#        'Columbia', 'Rochester', 'Minneapolis', 'Portland', 'Saint Paul',
#        'Aurora', 'Charlotte', 'Orland Park', 'Urbandale', 'Columbus',
#        'Bristol', 'Wilmington', 'Bloomington', 'Phoenix', 'Roseville',
#        'Independence', 'Pasadena', 'Newark', 'Franklin', 'Scottsdale',
#        'San Jose', 'Edmond', 'Carlsbad', 'San Antonio', 'Monroe',
#        'Fairfield', 'Grand Prairie', 'Redlands', 'Hamilton', 'Westfield',
#        'Akron', 'Denver', 'Dallas', 'Whittier', 'Saginaw', 'Medina',
#        'Dublin', 'Detroit', 'Tampa', 'Santa Clara', 'Lakeville',
# ...

# %%
df['City'].dtypes
# Out:
# dtype('O')

# %%
df['State'].dtypes
# Out:
# dtype('O')

# %%
df['State'].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
df['Region'].dtypes
# Out:
# dtype('O')

# %%
df['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df['Category'].dtypes
# Out:
# dtype('O')

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df['Sub-Category'].dtypes
# Out:
# dtype('O')

# %%
df['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
df['Sales'].dtypes
# Out:
# dtype('float64')

# %%
df['Sales'].unique()
# Out:
# array([261.96 , 731.94 ,  14.62 , ..., 437.472,  97.98 , 243.16 ])

# %%
df['Quantity'].dtypes
# Out:
# dtype('int64')

# %%
df['Quantity'].unique()
# Out:
# array([ 2,  3,  5,  7,  4,  6,  9,  1,  8, 14, 11, 13, 10, 12],
#       dtype=int64)

# %%
df['Discount'].dtypes
# Out:
# dtype('float64')

# %%
df['Discount'].unique()
# Out:
# array([0.  , 0.45, 0.2 , 0.8 , 0.3 , 0.5 , 0.7 , 0.6 , 0.32, 0.1 , 0.4 ,
#        0.15])

# %%
df['Profit'].dtypes
# Out:
# dtype('float64')

# %%
df['Profit'].unique()
# Out:
# array([ 41.9136, 219.582 ,   6.8714, ...,  14.25  ,   4.1028,  72.948 ])

# %% [markdown]
# **No stuctural errors in ourdataset**

# %% [markdown]
# ## Outlier

# %%
df.plot(kind = "box",subplots = True,layout = (3,2),figsize = (14,12))
plt.show()

# %% [markdown]
# ### Histogram

# %% [markdown]
# **Sales**

# %%
plt.style.use("classic")

# %%
df["Sales"].plot(kind="hist",
                  xlabel="number of Sales",
                  title = "Histogram of number of Sales",
                  color = '#fc5603',
                  figsize = (4,3)
                           
                           )
# Out:
# <Axes: title={'center': 'Histogram of number of Sales'}, xlabel='number of Sales', ylabel='Frequency'>

# %% [markdown]
# #### Quantity

# %%
plt.style.use("classic")

# %%
df["Quantity"].plot(kind="hist",
                  xlabel="Quantity",
                  title = "Histogram of quantity of sales",
                  color = '#fc5603',
                  figsize = (4,3)
                           
                           )
# Out:
# <Axes: title={'center': 'Histogram of quantity of sales'}, xlabel='Quantity', ylabel='Frequency'>

# %% [markdown]
# ### Discount

# %%
df["Discount"].plot(kind="hist",
                  xlabel="Discount",
                  title = "Histogram of discount ",
                  color = '#fc5603',
                  figsize = (4,3)
                           
                           )
# Out:
# <Axes: title={'center': 'Histogram of discount '}, xlabel='Discount', ylabel='Frequency'>

# %% [markdown]
# ### Profit

# %%
df['Profit'].plot(kind = 'hist',
                 xlabel = 'Profit',
                 title = 'Histogram of profit of sales',
                 color = '#9932a8',
                 figsize = (4,3))
# Out:
# <Axes: title={'center': 'Histogram of profit of sales'}, xlabel='Profit', ylabel='Frequency'>

# %% [markdown]
# ### Categorical

# %% [markdown]
# count,  Bar plot, Pie chart

# %%
df.head(2)
# Out:
#       Ship Mode   Segment        Country       City     State Region  \
# 0  Second Class  Consumer  United States  Henderson  Kentucky  South
# 1  Second Class  Consumer  United States  Henderson  Kentucky  South
#
#     Category Sub-Category   Sales  Quantity  Discount    Profit
# 0  Furniture    Bookcases  261.96         2       0.0   41.9136
# 1  Furniture       Chairs  731.94         3       0.0  219.5820

# %% [markdown]
# #### Bar plot

# %%
df['Ship Mode'].value_counts().plot(kind = 'bar',color = ['purple','#f57842','#42f542','#919991'],figsize =(4,5))
# Out:
# <Axes: xlabel='Ship Mode'>

# %% [markdown]
# ##### Segment

# %%
df['Segment'].value_counts().plot(kind = 'bar', 
                                      color = ['#f25d3f','#f2873f','#f2b03f'],
                                      figsize=(5,4))
# Out:
# <Axes: xlabel='Segment'>

# %%
df['State'].value_counts().plot(kind = 'barh', figsize = (13,12),color = ['#82a4f5','#f5a742'])
# Out:
# <Axes: ylabel='State'>

# %%
df["Category"].value_counts().plot(kind = "bar",xlabel = "Category",color =['pink','orange','green'],figsize=(3,3))
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# ### count plot

# %%
sns.countplot(data = df,x = "Category",color = 'orange')
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %% [markdown]
# ### Pie chart

# %%
(df["Region"].value_counts()/len(df["Region"])*100).plot(kind = "pie",
                                                               ylabel = 'percentage',
                                                                figsize = (6,7),
                                                                autopct = '%1.1f%%')
# Out:
# <Axes: ylabel='percentage'>

# %%
(df["Sub-Category"].value_counts()/len(df["Sub-Category"])*100).plot(kind = "pie",
                                                               ylabel = 'percentage',
                                                                figsize = (6,7),
                                                                autopct = '%1.1f%%')
# Out:
# <Axes: ylabel='percentage'>

# %% [markdown]
# ### Bivariate

# %% [markdown]
# Categorical & categorical, categorical and numerical , numerical to numerical

# %%
sns.countplot(data = df,x = "Ship Mode", hue = "Region")              #
# Out:
# <Axes: xlabel='Ship Mode', ylabel='count'>

# %%
df.plot("Profit","Discount",kind = "scatter",figsize = (6,5))
# Out:
# <Axes: xlabel='Profit', ylabel='Discount'>

# %% [markdown]
# ### Multivariate

# %%
df.corr(numeric_only = True)
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200491 -0.028600  0.479077
# Quantity  0.200491  1.000000  0.008402  0.066093
# Discount -0.028600  0.008402  1.000000 -0.219927
# Profit    0.479077  0.066093 -0.219927  1.000000

# %%
sns.heatmap(df.corr(numeric_only = True),annot = True)
# Out:
# <Axes: >

# %% [raw]
# **Disount and profit--- negatively strong relation.
# **

# %%
sns.pairplot(df)

# %% [markdown]
# #### summary

# %% [raw]
# We get most sale and profit from california and new york.
# The category that is most popular in these two states is office products.
# Most popular Sub-categories in office products are paper and Binders.
# Most used ship mode is standard mode.
